# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append("../code")

# %%
import loaders.cityprotect as cp

# %%
prop_list = ["Breaking & Entering", "Property Crime", "Theft of Vehicle", "Theft from Vehicle", "Theft"]
violent_list = ["Assault", "Robbery", "Sexual Offense", "Homicide", "Rape", "Other Violent Offense"]

# %%
dept = "San Pablo Police Department"

# %%
df = cp.cityprotect("../data/raw_data/{}".format(dept.replace(" ","_")))
# Out:
# Loading from 24 files.
# Data file ../data/raw_data/San_Pablo_Police_Department/Jul_Sep_2022_San_Pablo_Police_Department_report.csv is empty.
# Data file ../data/raw_data/San_Pablo_Police_Department/Oct_Dec_2022_San_Pablo_Police_Department_report.csv is empty.

# %%
reclassification_dir = {"Theft": ["theft", "burglary", "larceny"],
                        "Property Crime": ["property crime", "vandalism"],
                        "Assault": ["assault"],
                        "Robbery": ["robbery"],
                        "Homicide": ["homicide", "murder"],
                        "Sexual Offense": ["sexual assault", "rape"],
                        "Other Violent Offense": ["shooting", "shots fired", "car jacking", "carjacking", "kidnapping"]
                       }

# %%
unaccounted_parents = set(df["parentIncidentType"]) - set(prop_list) - set(violent_list)

# %%
for parent, words in reclassification_dir.items():
    for word in words:
        df.loc[df["parentIncidentType"].isin(unaccounted_parents) &
               df["incidentType"].str.contains(word, case=False), "parentIncidentType"]= parent

# %%
df[df["parentIncidentType"].isin(prop_list)]["incidentType"].value_counts()
# Out:
# VC 10851 VEHICLE THEFT                                           1230
# THEFT                                                            1110
# PC 488 PETTY THEFT                                                849
# PC 459A AUTO BURGLARY                                             665
# PC 594 VANDALISM                                                  627
# MOTOR VEHICLE THEFT                                               587
# DAMAGE TO PROPERTY/VANDALISM                                      477
# BURGLARY                                                          362
# PC 602 TRESPASSING                                                354
# PC 487 GRAND THEFT                                                225
# PC 459R RESIDENTIAL BURGLARY                                      162
# PC 459C COMMERCIAL BURGLARY                                       153
# PC 530 5 IDENTITY THEFT                                           118
# PC 470 FORGERY                                                     77
# VC 10852 TAMPER WITH VEH (EC)                                      67
# IDENTITY THEFT                                                     50
# LARCENY                                                            45
# PC 484 PETTY THEFT                                                 44
# PC 459 BURGLARY                                                    44
# PC 466 POSSESSION OF BURGLAR'S TOOLS                               43
# MAIL THEFT                                                         35
# PC 476 FORGERY OF ALTERED NOTES                                    33
# PC 496 RECEIVING STOLEN PROPERTY                                   33
# TITLE 18 TITLE 18                                                  30
# RECOVERED PROPERTY RECOVERED PROPERTY (EC)                         28
# PC 530 UNAUTHORIZED USE OF PERSONAL IDENTIFYING INFORMATION        21
# VEHICLE BURGLARY (PC459)                                           20
# VANDALISM                                                          18
# PC 484 G FRAUDULENT USE OF ACCESS CARD                             18
# PC 503 M EMBEZZLEMENT                                              15
# Other;THEFT                                                        14
# Other;DAMAGE TO PROPERTY/VANDALISM                                 13
# Other;MOTOR VEHICLE THEFT                                          11
# FRAUD FRAUD                                                        10
# Other;BURGLARY                                                      9
# PC 537(A)(1) DEFRAUDING INNKEEPER (EC)                              6
# 459A USED FOR PC 459A ON COPLOGIC;PC 459A AUTO BURGLARY             4
# PC 475 FORGERY WITH INTENT TO DEFRAUD                               4
# PC 460 2 COMMERCIAL BURGLARY                                        3
# PC 460 B AUTO/NON-DWELLING BURGLARY                                 3
# PC 664/487 ATTEMPTED GRAND THEFT                                    3
# EMBEZZLEMENT EMBEZZLEMENT                                           2
# PC 532 THEFT BY FALSE PRETENSE (SP)                                 2
# STOLEN PROPERTY STOLEN PROPERTY                                     1
# PC 664/488 ATTEMPTED PETTY THEFT                                    1
# STOLEN PROPERTY STOLEN PROPERTY;PC 488 PETTY THEFT                  1
# BURGLARY;TRESPASSING                                                1
# PC 666 PRIOR FELONY THEFT CONVICTION                                1
# BURG/AUTO BURGLARY/AUTO                                             1
# motor vehicle theft                                                 1
# THEFT;CFS PT PART TIME                                              1
# MOTOR VEHICLE THEFT;CFS T TRAFFIC STOP                              1
# BURGLARY;CAD S106C-Close Patrol (DPD)                               1
# DAMAGE TO PROPERTY/VANDALISM;RMS MOTOR VEHICLE OFFENSE: OTHER       1
# MOTOR VEHICLE THEFT;RMS FAMILY OFFENSE - 90F                        1
# Other;IDENTITY THEFT                                                1
# MOTOR VEHICLE THEFT;CAR JACKING                                     1
# BURGLARY;LOST PROPERTY                                              1
# Name: incidentType, dtype: int64

# %%
df[df["parentIncidentType"].isin(set(df["parentIncidentType"]) - set(prop_list) - set(violent_list))]
# Out:
#                  ccn                date          updateDate       city state  \
# 13177  2017-00001830 2017-01-01 07:00:00 2017-10-12 15:25:57  SAN PABLO    CA
# 13507  2017-00000024 2017-01-01 10:02:00 2017-10-12 15:25:56  SAN PABLO    CA
# 13509  2017-00000041 2017-01-01 18:40:00 2017-10-12 15:25:56  SAN PABLO    CA
# 13510  2017-00000056 2017-01-01 22:33:00 2017-10-12 15:25:56  SAN PABLO    CA
# 13526  2017-00000068 2017-01-02 02:09:00 2017-10-12 15:25:56  SAN PABLO    CA
# ...              ...                 ...                 ...        ...   ...
# 11726  2022-00008761 2022-04-07 15:18:46 2022-04-07 22:55:23  SAN PABLO    CA
# 11727  2022-00008762 2022-04-07 15:25:56 2022-04-07 22:55:23  SAN PABLO    CA
# 11721  2022-00008763 2022-04-07 16:47:56 2022-04-08 06:09:01  SAN PABLO    CA
# 11720  2022-00008764 2022-04-07 17:18:34 2022-04-08 06:09:01  SAN PABLO    CA
# 11719  2022-00008765 2022-04-07 19:23:33 2022-04-08 06:09:02  SAN PABLO    CA
#
#       postalCode              blocksizedAddress  \
# 13177        NaN         2400 Block MERRITT AVE
# 13507        NaN           1600 Block DOVER AVE
# 13509        NaN  EVERGREEN TER & SAN PABLO AVE
# 13510        NaN             1900 Block 23RD ST
# 13526        NaN                2200 Block RD20
# ...          ...                            ...
# 11726          .      13300 Block SAN PABLO AVE
# 11727          .                        VALE RD
# 11721          .        2300 Block EL PORTAL DR
# 11720      94806                     1 Block ST
# 11719      94806          13200 Block PABLO AVE
#
#                                             incidentType  parentIncidentType  \
# 13177                     PC 166.4 COURT ORDER VIOLATION               Other
# 13507                           PC 647 F DRUNK IN PUBLIC     Quality of Life
# 13509                     OSW MIS OUTSIDE WARRANT - MISD  Proactive Policing
# 13510  RECOVERED STOLEN VEHICLE RECOVERED STOLEN VEHICLE    Vehicle Recovery
# 13526                                        HIT AND RUN             Traffic
# ...                                                  ...                 ...
# 11726                                       TRAFFIC STOP               Other
# 11727                                       TRAFFIC STOP               Other
# 11721                                     SECURITY CHECK               Other
# 11720                                      MISCELLANEOUS               Other
# 11719                                     SECURITY CHECK               Other
#
#                                                narrative
# 13177                     PC 166.4 COURT ORDER VIOLATION
# 13507                           PC 647 F DRUNK IN PUBLIC
# 13509                     OSW MIS OUTSIDE WARRANT - MISD
# 13510  RECOVERED STOLEN VEHICLE RECOVERED STOLEN VEHICLE
# 13526                                        HIT AND RUN
# ...                                                  ...
# 11726                                       TRAFFIC STOP
# 11727                                       TRAFFIC STOP
# 11721                                     SECURITY CHECK
# 11720                                      MISCELLANEOUS
# 11719                                     SECURITY CHECK
#
# [47864 rows x 10 columns]

# %%
other_incidents = set(df[df["parentIncidentType"].isin(set(df["parentIncidentType"]) - set(prop_list) - set(violent_list))]["incidentType"])

# %%
other_incidents
# Out:
# {'459A USED FOR PC 459A ON COPLOGIC',
#  '911 DISCONNECT',
#  '911 DISCONNECT;PCAD - ENVIRONMENTAL',
#  'ABANDONED AUTO',
#  'ACCIDENT',
#  'ACCIDENT / NON-INJURY ACCIDENT / NON-INJURY',
#  'ALARM',
#  'ALARM;CAD S106-Special Assignment',
#  'ALARM;CAD S65-Foot Patrol',
#  'ALARM;CFS DISORDERLY',
#  'ANNOYING TELEPHONE CALLS',
#  'ARSON',
#  'BP VIOLATION BP VIOLATIONS - ALL OTHERS',
#  'BW FEL BENCH WARRANT FELONY',
#  'BW MIS BENCH WARRANT MISDEMEANOR',
#  'CIVIL MATTERS',
#  'COURT VIOLATION',
#  'CRUELTY TO ANIMALS',
#  'DEAD BODY',
#  'DISTURBANCE',
#  'DISTURBANCE;CAD S106-Special Assignment',
#  'DISTURBANCE;CFS CKPREM PREMISE CHECK',
#  'DISTURBANCE;TRAFFIC',
#  'DOMESTIC',
#  'DRUNK IN PUBLIC',
#  'DUI',
#  'ELDERLY / DEPENDENT ADULT ABUSE',
#  'EMBEZZLEMENT',
#  'EXTRA PATROL',
#  'FIREWORKS',
#  'FLAG DOWN',
#  'FLAG DOWN;CFS CKPREM PREMISE CHECK',
#  'FOLLOW UP',
#  'FOLLOW UP;WARRANT ARREST',
#  'FOUND PROPERTY',
#  'FRAUD',
#  'HIT AND RUN',
#  'HS 11350 POSSESS CONTROLLED SUBSTANCE',
#  'HS 11351 5 POSS/ETC BASE/ROCK COCAINE FOR SALE',
#  'HS 11351 POSSESS CONTROLLED SUBSTANCE FOR SALE',
#  'HS 11352 TRANSPORT/SELL CONTROLLED SUBSTANCE',
#  'HS 11357 A POSSESSION HASHISH',
#  'HS 11357 C POSS MARIJUANA MORE THAN 1 OZ',
#  'HS 11358 CULTIVATION OF MARIJUANA',
#  'HS 11359 POSSESS MARIJUANA/HASHISH FOR SALE',
#  'HS 11360 A TRANSPORT OF MARIJUANA',
#  'HS 11364 POSSESS CONTROLLED SUBSTANCE PARAPHERNALIA',
#  'HS 11368 FORGE/ALTER PRESCRIPTION',
#  'HS 11377 POSSESSION CONTROLLED SUBSTANCE',
#  'HS 11378 POSSESS CONTROLLED SUBSTANCE FOR SALE',
#  'HS 11379 TRANS/SELL CONTROLLED SUBSTANCE',
#  'HS 11550 HS 11550',
#  'HS 11590 NARCOTICS REGISTRANT',
#  'HS VIOLATION - ALL OTHERS HS VIOLATION - ALL OTHERS',
#  'ILLEGAL DUMPING',
#  'INDECENT EXPOSURE',
#  'INFORMATION ONLY',
#  'INFORMATION ONLY;PCAD - CHECK SECURITY',
#  'JUVENILE OUT OF CONTROL',
#  'LOITERING',
#  'LOST PROPERTY',
#  'LOST PROPERTY LOST PROPERTY',
#  'MAN DOWN',
#  'MENTAL PATIENT',
#  'MENTAL PATIENT;OUTSIDE ASSIST',
#  'MISC INFO MISC INFORMATION',
#  'MISCELLANEOUS',
#  'MISCELLANEOUS;CFS CKPREM PREMISE CHECK',
#  'MISCELLANEOUS;POLICE DISPATCH - SEARCH WARRANT SERVED',
#  'MISCELLANEOUS;RMS All OTHER OFFENSES - 90Z',
#  'MISCELLANEOUS;Traffic Complaint',
#  'MISSING PERSON / ADULT',
#  'MISSING PERSON / JUVENILE',
#  'MISSING PERSON MISSING PERSON',
#  'MUSIC',
#  'NARCOTICS',
#  'OPEN DOOR',
#  'OSW FEL OUTSIDE WARRANT - FELONY',
#  'OSW MIS OUTSIDE WARRANT - MISD',
#  'OUTSIDE ASSIST',
#  'OUTSIDE ASSIST OUTSIDE ASSIST',
#  'Other',
#  'Other;911 DISCONNECT',
#  'Other;ABANDONED AUTO',
#  'Other;ACCIDENT',
#  'Other;ALARM',
#  'Other;CIVIL MATTERS',
#  'Other;COURT VIOLATION',
#  'Other;DEAD BODY',
#  'Other;DISTURBANCE',
#  'Other;DOMESTIC',
#  'Other;DRUNK IN PUBLIC',
#  'Other;DUI',
#  'Other;EXTRA PATROL',
#  'Other;FIREWORKS',
#  'Other;FLAG DOWN',
#  'Other;FOLLOW UP',
#  'Other;FOUND PROPERTY',
#  'Other;FRAUD',
#  'Other;Financial Crimes',
#  'Other;HIT AND RUN',
#  'Other;ILLEGAL DUMPING',
#  'Other;INDECENT EXPOSURE',
#  'Other;INFORMATION ONLY',
#  'Other;JUVENILE OUT OF CONTROL',
#  'Other;MENTAL PATIENT',
#  'Other;MISCELLANEOUS',
#  'Other;MISSING PERSON / ADULT',
#  'Other;MUSIC',
#  'Other;Motorist Assist',
#  'Other;OUTSIDE ASSIST',
#  'Other;PEDESTRIAN STOP',
#  'Other;RECOVERED STOLEN VEHICLE',
#  'Other;REGISTRATIONS',
#  'Other;SECURITY CHECK',
#  'Other;STAKE-OUT',
#  'Other;SUICIDE / ATTEMPT',
#  'Other;SUSPICIOUS EVENT',
#  'Other;SUSPICIOUS PERSON',
#  'Other;SUSPICIOUS VEHICLE',
#  'Other;THREATS',
#  'Other;TRAFFIC / MISCELLANEOUS',
#  'Other;TRAFFIC STOP',
#  'Other;TRESPASSING',
#  'Other;WANTED PERSON',
#  'Other;WEAPONS',
#  'Other;WELFARE CHECK',
#  'PC 1203.2 PROBATION VIOLATION',
#  'PC 1203.2 PROBATION VIOLATION;PC 602 TRESPASSING',
#  'PC 148 5 FALSE POLICE REPORT',
#  'PC 148 RESISTING ARREST',
#  'PC 1551 FUGITIVE WRNT ARREST',
#  'PC 166.4 COURT ORDER VIOLATION',
#  'PC 236 FALSE IMPRISONMENT',
#  'PC 25400 CONCEALED FIREARM',
#  'PC 273 6 VIOLATION OF RESTRAINING ORDER',
#  'PC 273 A CHILD ABUSE',
#  'PC 273(d) Corproal Injury to a Child',
#  'PC 273.6 VIOLATION OF COURT ORDER-DOMESTIC VIOLENCE',
#  'PC 278 CHILD STEALING',
#  'PC 3056 PAROLE VIOLATION',
#  'PC 368 ELDER ABUSE',
#  'PC 374 LITTERING',
#  'PC 415 DISTURBING THE PEACE',
#  'PC 417 EXHIBITING FIREARM IN NEGLIGENT MANNER',
#  'PC 422 CRIMINAL THREATS',
#  'PC 451 ARSON',
#  'PC 452(A) UNLAWFUL FIRE',
#  'PC 485 PC 485 (EC)',
#  'PC 529 FALSE PERSONATION OF ANOTHER',
#  'PC 597 CRUELTY TO ANIMALS',
#  'PC 626 DISTURBANCE UPON SCHOOL PROPERTY',
#  'PC 646 STALKING',
#  'PC 647 6 ANNOY/MOLEST CHILD UNDER 18YRS',
#  'PC 647 F DRUNK IN PUBLIC',
#  'PC 647 H PROWLING',
#  'PC 653 M ANNOYING TELEPHONE CALLS',
#  'PC 69 THREATS ON PEACE OFFICER',
#  'PC 71 THREATS ON PEACE OFFICER',
#  'PC VIOLATION - ALL OTHERS PC VIOLATION - ALL OTHERS',
#  'PEDESTRIAN STOP',
#  'PEDESTRIAN STOP;RMS All OTHER OFFENSES - 90Z',
#  'PENAL CODE / MISC',
#  'PPD ANIMAL CALLS - NOT DOG',
#  'PPD LOT CLEAR',
#  'PROWLER',
#  'RECOVERED PROPERTY RECOVERED PROPERTY (EC);RECOVERED STOLEN VEHICLE RECOVERED STOLEN VEHICLE',
#  'RECOVERED STOLEN VEHICLE',
#  'RECOVERED STOLEN VEHICLE RECOVERED STOLEN VEHICLE',
#  'REGISTRATIONS',
#  'SEARCH WARRANT',
#  'SECURITY CHECK',
#  'SECURITY CHECK;CAD S26-Disorderly',
#  'SECURITY CHECK;PCAD - DISTURBANCE',
#  'SECURITY CHECK;PCAD - HARASSMENT',
#  'SECURITY CHECK;PCAD - PERSON INCIDENT',
#  'SECURITY CHECK;POLICE DISPATCH - CHECK SECURITY',
#  'SECURITY CHECK;POLICE DISPATCH - OFF DUTY EMPLOYMENT',
#  'SECURITY CHECK;[TA] TRAFFIC ACCIDENT',
#  'SPEEDING',
#  'STAKE-OUT',
#  'STALKING',
#  'SUICIDE',
#  'SUICIDE / ATTEMPT',
#  'SUSPICIOUS EVENT',
#  'SUSPICIOUS EVENT SUSPICIOUS EVENT',
#  'SUSPICIOUS EVENT;FRESP',
#  'SUSPICIOUS PERSON',
#  'SUSPICIOUS PERSON;CFS T TRAFFIC STOP',
#  'SUSPICIOUS PERSON;POLICE DISPATCH - CHECK SECURITY',
#  'SUSPICIOUS VEHICLE',
#  'THREATS',
#  'TRAFFIC / MISCELLANEOUS',
#  'TRAFFIC STOP',
#  'TRESPASSING',
#  'VC 12500 A UNLICENSED DRIVER',
#  'VC 14601 1A SUSPENDED DRIVERS LICENSE',
#  'VC 14601 2(A) SUSPENDED DUE TO DUI',
#  'VC 14601 5(A) DRIVING ON SUSPENDED/REVOKED LIC/ALCOHOL RELATED',
#  'VC 20001 A HIT AND RUN FELONY',
#  'VC 20002 A HIT AND RUN MISDEMEANOR',
#  'VC 23103 A RECKLESS DRIVING',
#  'VC 23109 A STREET RACING',
#  'VC 23152 A DUI',
#  'VC 23152 B DUI ALCOHOL /0.10 PERCENT',
#  'VC 23153 A DRIVING UNDER INFLUENCE-ALCOHOL/DRUGS CAUSING INJURY',
#  'VC 23222 B POSSESSION OF MARIJUANA/OPEN CONTAINER WHILE DRIVING;VC 23152 B DUI ALCOHOL /0.10 PERCENT',
#  'VC 23550(A) DUI W/PRIORS',
#  'VC 2800 FLEEING/EVADING',
#  'VC 31 FALSE INFORMATIO TO PEACE OFFICER',
#  'VC/NOT LISTED ABOVE VEHICLE CODE/NOT LISTED ABOVE',
#  'VEHICLE TAMPERING',
#  'WANTED PERSON',
#  'WANTED PERSON WANTED PERSON',
#  'WARRANT ARREST WARRANT ARREST',
#  'WARRANT ARREST WARRANT ARREST;BW MIS BENCH WARRANT MISDEMEANOR',
#  'WARRANT ARREST WARRANT ARREST;OSW MIS OUTSIDE WARRANT - MISD',
#  'WEAPON VIOLATION WEAPON VIOLATION',
#  'WEAPONS',
#  'WELFARE CHECK',
#  'WELFARE CHECK;CAD S42-Traffic Stop',
#  'WELFARE CHECK;CFS T TRAFFIC STOP',
#  'WELFARE CHECK;SUICIDE / ATTEMPT',
#  'WI 300 CHILD NEGLECT',
#  'WI 5150 MENTAL DISORDER',
#  'WI 601 2 RUNAWAY JUVENILE',
#  'WI 601 JUVENILE OUT OF CONTROL',
#  'WI 777 VIOLATION OF COURT ORDER'}

# %%
violent_words = ["KIDNAPPING", "MURDER", "CAR JACKING", "CARJACKING", 
                 "SHOOTING", "SHOTS FIRED",
                 "ASSAULT", "ROBBERY", "SEXUAL ASSUALT", "RAPE", "HOMICIDE"]

# %%
any(word in inc for word in violent_words for inc in other_incidents)
# Out:
# False

# %%
{inc for inc in other_incidents if any(word in inc for word in violent_words) }
# Out:
# set()

# %%
df["parentIncidentType"].value_counts()
# Out:
# Other                               37424
# Traffic                              5903
# Theft                                3389
# Property Crime                       1989
# Proactive Policing                   1567
# Vehicle Recovery                     1540
# Quality of Life                      1424
# Theft of Vehicle                     1231
# Assault                              1158
# Breaking & Entering                  1027
# Other Violent Offense                 487
# Robbery                               435
# Sexual Offense                        150
# Homicide                               20
# Theft from Vehicle                      3
# Other ;Proactive Policing               2
# Property Crime ;Vehicle Recovery        2
# Other ;Traffic                          1
# Other ;Property Crime                   1
# Name: parentIncidentType, dtype: int64

# %%
df[df["parentIncidentType"]=="Theft"]["incidentType"].value_counts()
# Out:
# THEFT                                                      1110
# PC 488 PETTY THEFT                                          849
# MOTOR VEHICLE THEFT                                         587
# BURGLARY                                                    362
# PC 487 GRAND THEFT                                          225
# IDENTITY THEFT                                               50
# LARCENY                                                      45
# PC 484 PETTY THEFT                                           44
# MAIL THEFT                                                   35
# VEHICLE BURGLARY (PC459)                                     20
# Other;THEFT                                                  14
# Other;MOTOR VEHICLE THEFT                                    11
# Other;BURGLARY                                                9
# PC 537(A)(1) DEFRAUDING INNKEEPER (EC)                        6
# 459A USED FOR PC 459A ON COPLOGIC;PC 459A AUTO BURGLARY       4
# PC 664/487 ATTEMPTED GRAND THEFT                              3
# PC 532 THEFT BY FALSE PRETENSE (SP)                           2
# STOLEN PROPERTY STOLEN PROPERTY                               1
# PC 664/488 ATTEMPTED PETTY THEFT                              1
# STOLEN PROPERTY STOLEN PROPERTY;PC 488 PETTY THEFT            1
# BURGLARY;TRESPASSING                                          1
# PC 666 PRIOR FELONY THEFT CONVICTION                          1
# BURG/AUTO BURGLARY/AUTO                                       1
# THEFT;CFS PT PART TIME                                        1
# MOTOR VEHICLE THEFT;CFS T TRAFFIC STOP                        1
# BURGLARY;CAD S106C-Close Patrol (DPD)                         1
# MOTOR VEHICLE THEFT;RMS FAMILY OFFENSE - 90F                  1
# Other;IDENTITY THEFT                                          1
# MOTOR VEHICLE THEFT;CAR JACKING                               1
# BURGLARY;LOST PROPERTY                                        1
# Name: incidentType, dtype: int64

# %%
df.loc[df["parentIncidentType"].isin(unaccounted_parents) &
       df["incidentType"].str.contains("theft", case=False), "parentIncidentType"]= "NewTheft"

# %%
df[df["parentIncidentType"]=="NewTheft"]

# %%
df[df["incidentType"].str.contains("shooting", case=False)]

# %%
any([True, False, True, True])

# %%
df["incidentType"].str.contains("shooting", case=False)
