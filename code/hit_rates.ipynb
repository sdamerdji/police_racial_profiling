# %%
import pandas as pd
import numpy as np
from datetime import datetime

from astral import Observer
from astral.sun import sun
from pytz import timezone
from timezonefinder import TimezoneFinder
import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency

# %%
sf = pd.read_csv('../data/raw_data/san_francisco.csv', low_memory=False)

# %%
sf.columns
# Out:
# Index(['raw_row_number', 'date', 'time', 'location', 'lat', 'lng', 'district',
#        'subject_age', 'subject_race', 'subject_sex', 'type', 'arrest_made',
#        'citation_issued', 'warning_issued', 'outcome', 'contraband_found',
#        'search_conducted', 'search_vehicle', 'search_basis', 'reason_for_stop',
#        'raw_search_vehicle_description', 'raw_result_of_contact_description'],
#       dtype='object')

# %%
sum(sf['search_conducted'] == True)
# Out:
# 53381

# %%
sum(sf['search_vehicle'] == True)
# Out:
# 53381

# %%
sf['contraband_found'].value_counts()
# Out:
# False    45405
# True      7976
# Name: contraband_found, dtype: int64

# %%
sf['arrest_made']
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 905065    False
# 905066    False
# 905067    False
# 905068    False
# 905069    False
# Name: arrest_made, Length: 905070, dtype: bool

# %%
denominator = sf.query('search_vehicle == True')

# %%
denominator.loc[:, 'contraband_found'] = pd.to_numeric(denominator['contraband_found'])

# %%
denominator
# Out:
#                  raw_row_number        date      time  \
# 23                       869944  2014-08-01  02:32:00
# 29                       869950  2014-08-01  05:20:00
# 125                      870046  2014-08-01  14:28:00
# 127                      870048  2014-08-01  14:34:00
# 134                      870055  2014-08-01  15:21:00
# ...                         ...         ...       ...
# 904975                   892915  2014-10-31  17:59:00
# 905024                   892964  2014-10-31  21:37:00
# 905028                   892968  2014-10-31  21:48:00
# 905048                   892988  2014-10-31  22:50:00
# contraband_found            NaN         NaN       NaN
#
#                                    location        lat         lng district  \
# 23                             HOWARD & 9TH  37.775007 -122.413181      NaN
# 29                     22ND AV. & GEARY BL.  37.780417 -122.481385      NaN
# 125               WEST POINT @ MIDDLE POINT  37.735271 -122.379442      NaN
# 127                      HAIGHT ST & PIERCE  37.771696 -122.433752      NaN
# 134                          3RD @ WILLIAMS  37.729294 -122.392758      NaN
# ...                                     ...        ...         ...      ...
# 904975                     21ST & FOLSOM ST  37.757510 -122.415048      NaN
# 905024                       3RD ST/QUESADA  37.733171 -122.391221      NaN
# 905028                             106 FERN  37.788274 -122.420637      NaN
# 905048                           3RD/ INNES  37.739494 -122.388972      NaN
# contraband_found                        NaN        NaN         NaN      NaN
#
#                   subject_age            subject_race subject_sex  ...  \
# 23                        NaN                   white        male  ...
# 29                        NaN  asian/pacific islander        male  ...
# 125                       NaN                   black        male  ...
# 127                       NaN                   white        male  ...
# 134                       NaN                   black        male  ...
# ...                       ...                     ...         ...  ...
# 904975                    NaN                hispanic        male  ...
# 905024                    NaN                   black        male  ...
# 905028                    NaN                   black        male  ...
# 905048                    NaN                   black        male  ...
# contraband_found          NaN                     NaN         NaN  ...
#
#                  citation_issued  warning_issued   outcome  contraband_found  \
# 23                           1.0             0.0  citation               0.0
# 29                           0.0             0.0    arrest               0.0
# 125                          0.0             1.0   warning               0.0
# 127                          1.0             0.0  citation               1.0
# 134                          0.0             0.0    arrest               0.0
# ...                          ...             ...       ...               ...
# 904975                       1.0             0.0  citation               0.0
# 905024                       1.0             0.0  citation               0.0
# 905028                       0.0             1.0   warning               0.0
# 905048                       1.0             0.0  citation               0.0
# contraband_found             NaN             NaN       NaN               NaN
#
#                  search_conducted  search_vehicle  search_basis  \
# 23                            1.0             1.0         other
# 29                            1.0             1.0         other
# 125                           1.0             1.0         other
# 127                           1.0             1.0         other
# 134                           1.0             1.0         other
# ...                           ...             ...           ...
# 904975                        1.0             1.0         other
# 905024                        1.0             1.0       consent
# 905028                        1.0             1.0         other
# 905048                        1.0             1.0         other
# contraband_found              NaN             NaN           NaN
#
#                                             reason_for_stop  \
# 23                Mechanical or Non-Moving Violation (V.C.)
# 29                                                DUI Check
# 125                                                     NaN
# 127                                        Moving Violation
# 134                                                     NaN
# ...                                                     ...
# 904975            Mechanical or Non-Moving Violation (V.C.)
# 905024            Mechanical or Non-Moving Violation (V.C.)
# 905028                                     Moving Violation
# 905048                                     Moving Violation
# contraband_found                                        NaN
#
#                                      raw_search_vehicle_description  \
# 23                       Search Incident to Arrest, Negative Result
# 29                               Vehicle Inventory, Negative Result
# 125                         Search without Consent, Negative Result
# 127                         Search without Consent, Positive Result
# 134               Searched as a result of Probation or Parole Co...
# ...                                                             ...
# 904975                      Search without Consent, Negative Result
# 905024                         Search with Consent, Negative Result
# 905028                      Search without Consent, Negative Result
# 905048            Searched as a result of Probation or Parole Co...
# contraband_found                                                NaN
#
#                  raw_result_of_contact_description
# 23                                        Citation
# 29                               In Custody Arrest
# 125                                        Warning
# 127                                       Citation
# 134                              In Custody Arrest
# ...                                            ...
# 904975                                    Citation
# 905024                                    Citation
# 905028                                     Warning
# 905048                                    Citation
# contraband_found                               NaN
#
# [53382 rows x 22 columns]

# %%
disag = denominator.groupby('subject_race').sum()['contraband_found']
count = denominator.groupby('subject_race').count().iloc[:, 0]
summary = pd.DataFrame({'total_searches': count.values,
                        'contraband': disag.values,
                        'no_contraband': count.values - disag.values,
                        'p(contraband|search)': disag.values / count.values}, index=count.index)

# %%
round(summary, 2)
# Out:
#                         total_searches  contraband  no_contraband  \
# subject_race
# asian/pacific islander            2861      1033.0         1828.0
# black                            23622      2183.0        21439.0
# hispanic                         11445      1165.0        10280.0
# other                             3746       761.0         2985.0
# white                            11707      2834.0         8873.0
#
#                         p(contraband|search)
# subject_race
# asian/pacific islander                  0.36
# black                                   0.09
# hispanic                                0.10
# other                                   0.20
# white                                   0.24

# %%
_, p_value, *_ = chi2_contingency(summary[['contraband', 'no_contraband']])

# %%
p_value
# Out:
# 0.0
